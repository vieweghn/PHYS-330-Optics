# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-330-Optics/blob/main/HW07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P Prism: If you didn't do this for HW7, please do it for HW7. Find the index of refraction of the equilateral prism for the three hydrogen lines we measured in the lab.

# %% [markdown]
# P 10.3

# %% [markdown]
# P 10.8
