# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-330-Optics/blob/main/HW01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P 1.1 (Gauss' Law)

# %% [markdown]
# P 1.2 (Faraday's Law)

# %% [markdown]
# P 1.3 (Ampere's Law)

# %% [markdown]
# P 1.7

# %% [markdown]
# P 1.9
