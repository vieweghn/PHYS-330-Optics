# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-330-Optics/blob/main/Fresnel_Air_Glass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def alpha(theta_i, nt, ni):
  si = np.sin(theta_i)
  st = ni*si/nt
  theta_t = np.where(st<1.0, np.arcsin(st),1j)
  return np.cos(theta_t)/np.cos(theta_i)

def beta(nt, ni):
  return nt/ni

def rs(theta_i, nt, ni):
  return (1-alpha(theta_i, nt, ni)*beta(nt, ni))/(1+alpha(theta_i, nt, ni)*beta(nt, ni))

def ts(theta_i, nt, ni):
  return 2/(1+alpha(theta_i, nt, ni)*beta(nt, ni))

def rp(theta_i, nt, ni):
  return (alpha(theta_i, nt, ni) - beta(nt, ni))/(alpha(theta_i, nt, ni) + beta(nt, ni))

def tp(theta_i, nt, ni):
  return 2/(alpha(theta_i, nt, ni) + beta(nt, ni))

# %%
theta_i = np.linspace(0, np.pi/2, 100)
nt = 1.5
ni = 1.0

plt.plot(np.degrees(theta_i), rp(theta_i, nt, ni), 'r',label="rp")
plt.plot(np.degrees(theta_i), rs(theta_i, nt, ni),'r--',label="rs")
plt.plot(np.degrees(theta_i), tp(theta_i, nt, ni), 'b',label="tp")
plt.plot(np.degrees(theta_i), ts(theta_i, nt, ni),'b--',label="ts")
plt.grid()
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
nt = 1.0
ni = 1.5

plt.plot(np.degrees(theta_i), rp(theta_i, nt, ni), 'r',label="rp")
plt.plot(np.degrees(theta_i), rs(theta_i, nt, ni),'r--',label="rs")
plt.plot(np.degrees(theta_i), tp(theta_i, nt, ni), 'b',label="tp")
plt.plot(np.degrees(theta_i), ts(theta_i, nt, ni),'b--',label="ts")
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2015020651.py:4: RuntimeWarning: invalid value encountered in arcsin
#   theta_t = np.where(st<1.0, np.arcsin(st),1j)
