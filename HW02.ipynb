# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/PHYS-330-Optics/blob/main/HW02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# P 2.3

# %% [markdown]
# P 2.4

# %% [markdown]
# P 2.8

# %% [markdown]
# P 2.10

# %% [markdown]
# P 2.11
